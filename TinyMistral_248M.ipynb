# %% [markdown]
# <a href="https://colab.research.google.com/github/VexterLabs/SkyNet/blob/main/TinyMistral_248M.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U transformers

# %% [markdown]
# ## Local Inference on GPU
# Model page: https://huggingface.co/Locutusque/TinyMistral-248M
#
# ⚠️ If the generated code snippets do not work, please open an issue on either the [model repo](https://huggingface.co/Locutusque/TinyMistral-248M)
# 			and/or on [huggingface.js](https://github.com/huggingface/huggingface.js/blob/main/packages/tasks/src/model-libraries-snippets.ts) 🙏

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-generation", model="Locutusque/TinyMistral-248M")
# Out:
# config.json:   0%|          | 0.00/562 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/992M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/111 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/67.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/639 [00:00<?, ?B/s]

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("Locutusque/TinyMistral-248M")
model = AutoModelForCausalLM.from_pretrained("Locutusque/TinyMistral-248M")
# Out:
# Loading weights:   0%|          | 0/111 [00:00<?, ?it/s]
